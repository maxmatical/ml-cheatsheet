# %% [markdown]
# # Clustering with Sentence-BERT
# 1. split messages further into sentences (include commas)
# 2. add an additional `message_idx` (for aggregating later)
# 3. split df into 1 word and multi-word
#     - ignore 1 word df for now
# 4. encode sentences with sentence-bert
#     - scale to be non-negative
# 4. run nmf
# 5. aggregate at conv level
#     - sort by `["conv_id", "msg_idx"]`
#     - group by `conv_id`: concat text, concat topics, concat topic keywords

# %%
from collections import Counter
from pathlib import Path
from typing import Tuple
import pandas as pd
import numpy as np
from NMF_utils import *
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from joblib import dump
from tqdm import tqdm
from sentence_transformers import SentenceTransformer
import nltk

# %%
# settings
"""
couple models to try
 paraphrase-distilroberta-base-v2 
 paraphrase-TinyBERT-L6-v2 
 stsb-distilroberta-base-v2
 
"""
pretrained_model = "paraphrase-distilroberta-base-v2"
# set values for rest of script
best_num_topics = 200 
top_k = 3 # k for top_k topics
n_top_words = 5 # n for n_top_words (number of words for topic key words)
docweights_threshold = 0.75 # threshold for considering a topic is relevant in NMF
save_folder = "june18_bert"
Path(f"./nmf_topics/{save_folder}").mkdir(parents=True, exist_ok=True)
Path(f"./nmf_models/{save_folder}").mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # encoding tests

# %%
# sentence transformer test

model = SentenceTransformer(pretrained_model)

#Our sentences we like to encode
# sentences = ['This framework generates embeddings for each input sentence',
#     'Sentences are passed as a list of string.',
#     'The quick brown fox jumps over the lazy dog.']

# #Sentences are encoded by calling model.encode()
# embeddings = model.encode(sentences)

"""
can run something like
sentences = df["MESSAGE"]
embeddings = model.encode(sentences)
print(embeddings.shape) results in shape (n, 768)
print(np.amin(embeddings), np.amax(embeddings)) (typically somewhere between -5, 5)
"""
# Out:
# '\ncan run something like\nsentences = df["MESSAGE"]\nembeddings = model.encode(sentences)\nprint(embeddings.shape) results in shape (n, 768)\nprint(np.amin(embeddings), np.amax(embeddings)) (typically somewhere between -5, 5)\n'

# %%
# embeddings
# np.amax(embeddings), np.amin(embeddings)

# %%
df = pd.read_csv("freedom_intent_no_escalate.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  CLUSTER_ID MESSAGE                                SESSION_ID  \
# 0           2           0   netel  d63b71e0-e4c7-4012-822b-135f884dd90d:::4
# 1           3           0   netel  5241a58a-9b9a-422e-b451-3832ac96e1dc:::6
# 2          11           0   netel  b864d516-66b3-4223-a852-e4b428b7578d:::4
# 3          15           0   netel  719801fc-34c6-4ff9-8d7b-bb32d4de6766:::4
# 4          22           0   netel  3808e306-4e23-4292-94f3-d1fd1b9bfd33:::4
#
#   CHANNEL  MESSAGE_INTENT_1  MESSAGE_INTENT_CONFIDENCE_1  MESSAGE_INTENT_2  \
# 0     BOT                -1                           -1                -1
# 1     BOT                -1                           -1                -1
# 2     BOT                -1                           -1                -1
# 3     BOT                -1                           -1                -1
# 4     BOT                -1                           -1                -1
#
#    MESSAGE_INTENT_CONFIDENCE_2  MESSAGE_INTENT_3  MESSAGE_INTENT_CONFIDENCE_3  \
# 0                           -1                -1                           -1
# 1                           -1                -1                           -1
# 2                           -1                -1                           -1
# 3                           -1                -1                           -1
# 4                           -1                -1                           -1
#
#          MESSAGE_INTENT  MESSAGE_CONFIDENCE  IF_VALID_INTENT LANGUAGE
# 0  $shop_accessory_misc            0.953275             True       en
# 1  $shop_accessory_misc            0.953275             True       en
# 2  $shop_accessory_misc            0.953275             True       en
# 3  $shop_accessory_misc            0.953275             True       en
# 4  $shop_accessory_misc            0.953275             True       en

# %% [markdown]
# # Preprocessing

# %%
df = df[~df.MESSAGE.str.contains("""{ " com """)]
# add conv id and message id to sort by
df["conversation_id"] = df["SESSION_ID"].str.split(":::").str[0]
df["message_id"] = df["SESSION_ID"].str.split(":::").str[1].astype(int)
# sort to make grouping easier
# df = df.sort_values(by=["conversation_id", "message_id"])
df = df[["conversation_id", "message_id", "MESSAGE"]]
df.head(5)
# Out:
#                         conversation_id  message_id MESSAGE
# 0  d63b71e0-e4c7-4012-822b-135f884dd90d           4   netel
# 1  5241a58a-9b9a-422e-b451-3832ac96e1dc           6   netel
# 2  b864d516-66b3-4223-a852-e4b428b7578d           4   netel
# 3  719801fc-34c6-4ff9-8d7b-bb32d4de6766           4   netel
# 4  3808e306-4e23-4292-94f3-d1fd1b9bfd33           4   netel

# %% [markdown]
# split the messages further into sentences

# %%
# split the messages further into sentences
df = df.drop('MESSAGE', axis=1).join(df['MESSAGE'].str.split(r"[,.!?]", expand=True).stack().reset_index(level=1, drop=True).rename('MESSAGE'))
df.tail(10)
# Out:
#                            conversation_id  message_id  \
# 3525  8087c72a-3246-42ee-ac83-db6d87be6bfc           1
# 3525  8087c72a-3246-42ee-ac83-db6d87be6bfc           1
# 3526  e6c37c6b-52c8-4ed0-a02d-ec77d96ad839           3
# 3527  13d88447-fdc4-42ac-87d9-9bb1641a8062           1
# 3527  13d88447-fdc4-42ac-87d9-9bb1641a8062           1
# 3527  13d88447-fdc4-42ac-87d9-9bb1641a8062           1
# 3527  13d88447-fdc4-42ac-87d9-9bb1641a8062           1
# 3527  13d88447-fdc4-42ac-87d9-9bb1641a8062           1
# 3528                      3836504886472679          18
# 3529                      3473478809418490           5
#
#                                                 MESSAGE
# 3525                                  how can i do that
# 3525
# 3526  is there any deal to buy apple watch 6 in mont...
# 3527  hi i recently transferred my phone number from...
# 3527   i am unable to access it due to the fact that...
# 3527                   the account name is under neper
# 3527   i am looking to cancel the plan on the accoun...
# 3527                                          thank you
# 3528                                 have a great night
# 3529  i topped up my account online but i got nothin...

# %%
# add sentence_id to track message order for aggregation
# sort to make grouping easier
df = df.sort_values(by=["conversation_id", "message_id"])
df["sentence_id"] = df.groupby("conversation_id").cumcount()
df["session_id"] = df["conversation_id"]+"_"+df["sentence_id"].astype(str)
df.tail(10)
# Out:
#                            conversation_id  message_id  \
# 883   ff9ac61f-8f98-4516-9342-7aa1177514d9          20
# 1062  ff9ac61f-8f98-4516-9342-7aa1177514d9          22
# 1149  ff9ac61f-8f98-4516-9342-7aa1177514d9          24
# 73    ffb30da4-4274-4dde-a755-eb5160834e8c           4
# 39    ffb30da4-4274-4dde-a755-eb5160834e8c           6
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2           2
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2           2
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2           2
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2           2
# 247   ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2           5
#
#                                                 MESSAGE  sentence_id  \
# 883                                         data + talk            3
# 1062                                    more than 10 gb            4
# 1149                                 15 gb freedom data            5
# 73                                                netel            0
# 39                                                netel            1
# 3049                                              hello            0
# 3049   i purchased the cannes outdoor sofa however i...            1
# 3049                          are they machine washable            2
# 3049                                                               3
# 247                                  message with a rep            4
#
#                                   session_id
# 883   ff9ac61f-8f98-4516-9342-7aa1177514d9_3
# 1062  ff9ac61f-8f98-4516-9342-7aa1177514d9_4
# 1149  ff9ac61f-8f98-4516-9342-7aa1177514d9_5
# 73    ffb30da4-4274-4dde-a755-eb5160834e8c_0
# 39    ffb30da4-4274-4dde-a755-eb5160834e8c_1
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2_0
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2_1
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2_2
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2_3
# 247   ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2_4

# %%
# preprocess text
df["MESSAGE"] = df["MESSAGE"].str.replace("|".join(remove_words),'')# remove certain texts from messages
df['word_count'] = df['MESSAGE'].apply(word_count)
df['processed_text'] = df['MESSAGE'].apply(process_text)
df = df[df['processed_text'].map(lambda d: len(d)) > 0]
print(df.shape)
df.tail(10)
# Out:
# (3496, 7)
#                            conversation_id  message_id  \
# 1240  ff097a90-5972-46d1-845a-3c9a399b70bc           1
# 1883  ff93a689-8d1a-49c2-a5bc-54dd321707a3           1
# 859   ff9ac61f-8f98-4516-9342-7aa1177514d9           7
# 993   ff9ac61f-8f98-4516-9342-7aa1177514d9           9
# 1284  ff9ac61f-8f98-4516-9342-7aa1177514d9          14
# 883   ff9ac61f-8f98-4516-9342-7aa1177514d9          20
# 1062  ff9ac61f-8f98-4516-9342-7aa1177514d9          22
# 1149  ff9ac61f-8f98-4516-9342-7aa1177514d9          24
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2           2
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2           2
#
#                                                 MESSAGE  sentence_id  \
# 1240                                        i need help            0
# 1883  i am getting a phone for my son and looking to...            0
# 859                                         data + talk            0
# 993                                     less than 10 gb            1
# 1284                                              10 gb            2
# 883                                         data + talk            3
# 1062                                    more than 10 gb            4
# 1149                                 15 gb freedom data            5
# 3049   i purchased the cannes outdoor sofa however i...            1
# 3049                            are they macne washable            2
#
#                                   session_id  word_count  \
# 1240  ff097a90-5972-46d1-845a-3c9a399b70bc_0           3
# 1883  ff93a689-8d1a-49c2-a5bc-54dd321707a3_0          26
# 859   ff9ac61f-8f98-4516-9342-7aa1177514d9_0           3
# 993   ff9ac61f-8f98-4516-9342-7aa1177514d9_1           4
# 1284  ff9ac61f-8f98-4516-9342-7aa1177514d9_2           2
# 883   ff9ac61f-8f98-4516-9342-7aa1177514d9_3           3
# 1062  ff9ac61f-8f98-4516-9342-7aa1177514d9_4           4
# 1149  ff9ac61f-8f98-4516-9342-7aa1177514d9_5           4
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2_1          17
# 3049  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2_2           5
#
#                                          processed_text
# 1240                                       [need, help]
# 1883   [get, phone, son, look, plan, iphon, se, packag]
# 859                                        [data, talk]
# 993                                                [gb]
# 1284                                               [gb]
# 883                                        [data, talk]
# 1062                                               [gb]
# 1149                                [gb, freedom, data]
# 3049  [purchas, cann, outdoor, sofa, care, instruct,...
# 3049                                    [macn, washabl]

# %%
# df[df["conversation_id"]=="1895298307224761"]

# %% [markdown]
# ## split df into 2 dfs
# - df containing only 1 word sentences
# - df containing multiple sentences
#
# **ignore df containing only 1 word sentences for now**

# %%
df1 = df[df["processed_text"].str.len()==1]
df2 = df[df["processed_text"].str.len()!=1]
df2.head(5)
# Out:
#                            conversation_id  message_id  \
# 2608  001bede7-810d-4284-b289-c29ab8a12bba           2
# 2608  001bede7-810d-4284-b289-c29ab8a12bba           2
# 987   0024cce3-b115-4a79-88c7-604d046076df           5
# 3463  0028d3f2-964b-4903-bd37-3bb364459504           1
# 2591  00560815-b4b9-4919-bd75-5dbd07aadec2           5
#
#                                                 MESSAGE  sentence_id  \
# 2608                         i need to activate new sim            1
# 2608              but it's got getting activated online            2
# 987                                     account details            0
# 3463                     i would like to cancel service            0
# 2591  i have a balance of  but my wife 's account ag...            0
#
#                                   session_id  word_count  \
# 2608  001bede7-810d-4284-b289-c29ab8a12bba_1           7
# 2608  001bede7-810d-4284-b289-c29ab8a12bba_2           7
# 987   0024cce3-b115-4a79-88c7-604d046076df_0           2
# 3463  0028d3f2-964b-4903-bd37-3bb364459504_0           6
# 2591  00560815-b4b9-4919-bd75-5dbd07aadec2_0          16
#
#                              processed_text
# 2608                [need, activ, new, sim]
# 2608               [got, get, activ, onlin]
# 987                       [account, detail]
# 3463                       [cancel, servic]
# 2591  [balanc, wife, account, say, suspend]

# %%
df2['word_count'].describe()
# Out:
# count    2825.000000
# mean        9.804956
# std         7.598446
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        13.000000
# max       144.000000
# Name: word_count, dtype: float64

# %% [markdown]
# # Clustering on multi-word sentences

# %% [markdown]
# ## Encode text into embeddings
#
# - optionally scale for NMF

# %%
texts = list(df2['processed_text'])
model = SentenceTransformer(pretrained_model)

# %%
embeddings = model.encode(texts)

# %%
print(embeddings.shape)
print(np.amin(embeddings), np.amax(embeddings))
# Out:
# (2825, 768)
# -4.325707 5.028679

# %%
# scale embeddings to have min value 0
scaled_embeddings = embeddings + np.abs(np.amin(embeddings))
print(np.amin(scaled_embeddings), np.amax(scaled_embeddings))
# Out:
# 0.0 9.354385

# %% [markdown]
# ## Run NMF on embeddings

# %%
# Run the nmf model
nmf = NMF(
    n_components=best_num_topics,
    init='nndsvd',
    max_iter=500,
    l1_ratio=0.0,
    solver='cd',
    alpha=0.0,
    tol=1e-4,
    random_state=42,
).fit(scaled_embeddings)

# %% [markdown]
# ## Create topic groupings

# %%
docweights = nmf.transform(scaled_embeddings)

# %%
nmf.components_.shape
# Out:
# (200, 768)

# %% [markdown]
# ### get top k topics

# %%
# can go along each row

top_k_topics = get_top_k_topics(docweights, top_k = top_k)
top_k_topics[0], top_k_topics[1], top_k_topics[2], top_k_topics[3]
# Out:
# (array([66, 31, 92]),
#  array([ 27,  42, 100]),
#  array([104, 177,  66]),
#  array([177,   3, 100]))

# %%
# Creating a temp df with the sesion id and topic number to join on
# with top k topics
session_ids = df2['session_id'].tolist()

df_merge = pd.DataFrame({
    'session_id': session_ids,
})

# create 2*k columns, each wtih top k topics and their associated keywords
for i in range(top_k_topics.shape[1]):
    df_merge[f"topic_{i+1}"] = top_k_topics[:,i]
    # df_merge[f"topic_{i+1}_key_words"] = df_merge[f"topic_{i+1}"].map(topic_dict)
# df_merge["topic_key_words"] = df_merge["topic"].map(topic_dict)
df_merge.head(5)
# Out:
#                                session_id  topic_1  topic_2  topic_3
# 0  001bede7-810d-4284-b289-c29ab8a12bba_1       66       31       92
# 1  001bede7-810d-4284-b289-c29ab8a12bba_2       27       42      100
# 2  0024cce3-b115-4a79-88c7-604d046076df_0      104      177       66
# 3  0028d3f2-964b-4903-bd37-3bb364459504_0      177        3      100
# 4  00560815-b4b9-4919-bd75-5dbd07aadec2_0      192      138       42

# %%
df_topics2 = pd.merge(
    df2,
    df_merge,
    on='session_id',
    how='left'
)
df_topics2.tail(5)
# Out:
#                            conversation_id  message_id  \
# 2820  ff9ac61f-8f98-4516-9342-7aa1177514d9           7
# 2821  ff9ac61f-8f98-4516-9342-7aa1177514d9          20
# 2822  ff9ac61f-8f98-4516-9342-7aa1177514d9          24
# 2823  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2           2
# 2824  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2           2
#
#                                                 MESSAGE  sentence_id  \
# 2820                                        data + talk            0
# 2821                                        data + talk            3
# 2822                                 15 gb freedom data            5
# 2823   i purchased the cannes outdoor sofa however i...            1
# 2824                            are they macne washable            2
#
#                                   session_id  word_count  \
# 2820  ff9ac61f-8f98-4516-9342-7aa1177514d9_0           3
# 2821  ff9ac61f-8f98-4516-9342-7aa1177514d9_3           3
# 2822  ff9ac61f-8f98-4516-9342-7aa1177514d9_5           4
# 2823  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2_1          17
# 2824  ffbf37b3-2b93-4875-9cbb-d5f5dc0ed3e2_2           5
#
#                                          processed_text  topic_1  topic_2  \
# 2820                                       [data, talk]      100       33
# 2821                                       [data, talk]      100       33
# 2822                                [gb, freedom, data]      177      104
# 2823  [purchas, cann, outdoor, sofa, care, instruct,...      100      192
# 2824                                    [macn, washabl]       66      144
#
#       topic_3
# 2820       99
# 2821       99
# 2822        9
# 2823       33
# 2824      177

# %%
print(df_topics2["topic_1"].unique())
print(len(df_topics2["topic_1"].unique()))
# Out:
# [ 66  27 104 177 192  33  28 142 110  15  81 100 148   3  18  24 149 155
#  191 144 136  99  22 138 127 161 133  14  73  92  71  42  13  34 175 128
#   58  35  10 114 169 195  46  75   6 109  31  50]
# 48

# %% [markdown]
# ### Topics that pass a certain threshold

# %%
df_topics2[f"topics_threshold_>={docweights_threshold}"] = threshold_docweights(docweights, threshold = docweights_threshold)

# %%
df_topics2.head(5)
# Out:
#                         conversation_id  message_id  \
# 0  001bede7-810d-4284-b289-c29ab8a12bba           2
# 1  001bede7-810d-4284-b289-c29ab8a12bba           2
# 2  0024cce3-b115-4a79-88c7-604d046076df           5
# 3  0028d3f2-964b-4903-bd37-3bb364459504           1
# 4  00560815-b4b9-4919-bd75-5dbd07aadec2           5
#
#                                              MESSAGE  sentence_id  \
# 0                         i need to activate new sim            1
# 1              but it's got getting activated online            2
# 2                                    account details            0
# 3                     i would like to cancel service            0
# 4  i have a balance of  but my wife 's account ag...            0
#
#                                session_id  word_count  \
# 0  001bede7-810d-4284-b289-c29ab8a12bba_1           7
# 1  001bede7-810d-4284-b289-c29ab8a12bba_2           7
# 2  0024cce3-b115-4a79-88c7-604d046076df_0           2
# 3  0028d3f2-964b-4903-bd37-3bb364459504_0           6
# 4  00560815-b4b9-4919-bd75-5dbd07aadec2_0          16
#
#                           processed_text  topic_1  topic_2  topic_3  \
# 0                [need, activ, new, sim]       66       31       92
# 1               [got, get, activ, onlin]       27       42      100
# 2                      [account, detail]      104      177       66
# 3                       [cancel, servic]      177        3      100
# 4  [balanc, wife, account, say, suspend]      192      138       42
#
#                               topics_threshold_>=0.5  \
# 0          [12, 24, 26, 31, 33, 42, 46, 66, 92, 100]
# 1  [22, 27, 42, 66, 81, 92, 99, 100, 101, 104, 11...
# 2            [8, 61, 66, 85, 99, 104, 136, 177, 192]
# 3  [3, 17, 18, 33, 42, 46, 86, 92, 100, 104, 147,...
# 4  [29, 31, 35, 42, 48, 61, 71, 73, 101, 110, 116...
#
#                              topics_threshold_>=0.75
# 0                                   [12, 31, 66, 92]
# 1               [27, 42, 66, 81, 100, 104, 148, 177]
# 2                         [8, 66, 99, 104, 136, 177]
# 3                     [3, 42, 46, 92, 100, 104, 177]
# 4  [35, 42, 48, 61, 71, 73, 101, 110, 138, 150, 1...

# %% [markdown]
# ### map topics to their keywords
#
# **method 1 (doesnt work)**
# 1. filter df to just dfs that have topic that pass a certain threhsold
# 2. treat that as a document, and use n_gram counts
# 3. the top k most frequent n grams become the topic key words
#
# **method 2 (current method)**
# 1. filter df to just top topic
# 2. treat that as document and use n gram counts
# 3. the top k most frequent n grams become the topic key words

# %%
def get_top_k_keywords(df: pd.DataFrame, n_gram_range: Tuple[int, int] = (2, 5), k: int = 5):
    texts = list(df["processed_text"])
    counts = Counter() 
    for text in texts:
        for i in range(n_gram_range[0], n_gram_range[1]):
            counts.update(nltk.ngrams(text, 2))

    return [c[0] for c in counts.most_common(k)]

# %%
# df_tmp = df_topics2[df_topics2[f"topics_threshold_>={docweights_threshold}"].apply(lambda x: 2 in x)]
# print(df_tmp.shape)
# df_tmp.head(5)
# Out:
# (65, 15)
#                           conversation_id  message_id  \
# 50   029499a8-9c86-401d-b66a-9ba12bf2c068           5
# 61   044a8201-6808-4d37-a41a-753161fca415           1
# 95   07ab6e8d-6066-4b7f-86d5-0ade29db411d           4
# 132  0cee3efc-838f-4572-a196-b4b6fd651ea3           2
# 162  0f4676f7-de28-4f32-8446-8afab5bd7d66           2
#
#                                                MESSAGE  sentence_id  \
# 50       can i pay my bill before my auto payment date            4
# 61   how much do i need to pay you to buy out my pl...            0
# 95   i paid the bill it reflected on my bank statem...            0
# 132       i paid my bill april 29 via my cibc account             0
# 162                  but i still pay for a plan on it             4
#
#                                  session_id  word_count  \
# 50   029499a8-9c86-401d-b66a-9ba12bf2c068_4          10
# 61   044a8201-6808-4d37-a41a-753161fca415_0          15
# 95   07ab6e8d-6066-4b7f-86d5-0ade29db411d_0          16
# 132  0cee3efc-838f-4572-a196-b4b6fd651ea3_0          11
# 162  0f4676f7-de28-4f32-8446-8afab5bd7d66_4          11
#
#                                    processed_text  topic_1  topic_2  topic_3  \
# 50               [pay, bill, auto, payment, date]      142       66      104
# 61                  [need, pay, buy, plan, right]      142      177       33
# 95   [paid, bill, reflect, bank, statement, bill]      104       66       28
# 132            [paid, bill, april, cibc, account]      104       66       28
# 162                                   [pay, plan]       33      142       66
#
#                                 topics_threshold_>=0.5  \
# 50   [2, 10, 17, 24, 28, 33, 35, 42, 66, 99, 104, 1...
# 61   [2, 12, 18, 28, 33, 42, 66, 71, 73, 100, 142, ...
# 95   [2, 10, 15, 17, 18, 28, 33, 42, 66, 87, 99, 10...
# 132  [2, 10, 15, 17, 18, 28, 33, 42, 66, 87, 99, 10...
# 162  [2, 18, 30, 33, 35, 62, 66, 71, 95, 100, 142, ...
#
#                      topics_threshold_>=0.75  \
# 50   [2, 10, 28, 33, 66, 104, 142, 144, 175]
# 61             [2, 28, 33, 42, 73, 142, 177]
# 95   [2, 28, 42, 66, 99, 104, 127, 142, 175]
# 132  [2, 28, 42, 66, 99, 104, 127, 142, 175]
# 162                     [2, 33, 35, 66, 142]
#
#                                      topic_1_key_words  \
# 50   [(just, wonder), (just, got), (hey, just), (go...
# 61   [(just, wonder), (just, got), (hey, just), (go...
# 95   [(just, wonder), (just, got), (hey, just), (go...
# 132  [(just, wonder), (just, got), (hey, just), (go...
# 162  [(just, wonder), (just, got), (hey, just), (go...
#
#                                      topic_2_key_words  \
# 50   [(just, wonder), (just, got), (hey, just), (go...
# 61   [(just, wonder), (just, got), (hey, just), (go...
# 95   [(just, wonder), (just, got), (hey, just), (go...
# 132  [(just, wonder), (just, got), (hey, just), (go...
# 162  [(just, wonder), (just, got), (hey, just), (go...
#
#                                      topic_3_key_words
# 50   [(just, wonder), (just, got), (hey, just), (go...
# 61   [(just, wonder), (just, got), (hey, just), (go...
# 95   [(just, wonder), (just, got), (hey, just), (go...
# 132  [(just, wonder), (just, got), (hey, just), (go...
# 162  [(just, wonder), (just, got), (hey, just), (go...

# %%
# # get top k keywords for each topic
# topic_dict = {-1:""} # intitial condition
# for topic_num in tqdm(range(best_num_topics)):
#     # subset df_topics2 by if topic_num apprears in threshold topics
#     df_tmp = df_topics2[df_topics2[f"topics_threshold_>={docweights_threshold}"].apply(lambda x: 1 in x)]
#     if len(df_tmp):
#         topic_dict[topic_num] = get_top_k_keywords(df_tmp, n_gram_range=(2, 4), k=n_top_words)

# %%
# get top k keywords for each topic
topic_dict = {-1:""} # intitial condition
for topic_num in tqdm(sorted(df_topics2.topic_1.unique())):
    if topic_num != -1: # avoid cases where there's no topic (i.e. max topic has weight 0 in docweights)
        df_tmp = df_topics2[df_topics2["topic_1"]==topic_num]
        topic_dict[topic_num] = get_top_k_keywords(df_tmp, n_gram_range=(2, 4), k=n_top_words)
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 829.13it/s]

# %%
list(topic_dict.items())[:3]
# Out:
# [(-1, ''),
#  (3,
#   [('want', 'cancel'),
#    ('cancel', 'plan'),
#    ('need', 'cancel'),
#    ('cancel', 'home'),
#    ('home', 'internet')]),
#  (6,
#   [('want', 'chang'),
#    ('chang', 'address'),
#    ('chang', 'bill'),
#    ('bill', 'address'),
#    ('chang', 'bank')])]

# %%
# map topic dict to df_topic_2
for i in range(top_k_topics.shape[1]):
    df_topics2[f"topic_{i+1}_key_words"] = df_topics2[f"topic_{i+1}"].map(topic_dict)

df_topics2.head(5)
# Out:
#                         conversation_id  message_id  \
# 0  001bede7-810d-4284-b289-c29ab8a12bba           2
# 1  001bede7-810d-4284-b289-c29ab8a12bba           2
# 2  0024cce3-b115-4a79-88c7-604d046076df           5
# 3  0028d3f2-964b-4903-bd37-3bb364459504           1
# 4  00560815-b4b9-4919-bd75-5dbd07aadec2           5
#
#                                              MESSAGE  sentence_id  \
# 0                         i need to activate new sim            1
# 1              but it's got getting activated online            2
# 2                                    account details            0
# 3                     i would like to cancel service            0
# 4  i have a balance of  but my wife 's account ag...            0
#
#                                session_id  word_count  \
# 0  001bede7-810d-4284-b289-c29ab8a12bba_1           7
# 1  001bede7-810d-4284-b289-c29ab8a12bba_2           7
# 2  0024cce3-b115-4a79-88c7-604d046076df_0           2
# 3  0028d3f2-964b-4903-bd37-3bb364459504_0           6
# 4  00560815-b4b9-4919-bd75-5dbd07aadec2_0          16
#
#                           processed_text  topic_1  topic_2  topic_3  \
# 0                [need, activ, new, sim]       66       31       92
# 1               [got, get, activ, onlin]       27       42      100
# 2                      [account, detail]      104      177       66
# 3                       [cancel, servic]      177        3      100
# 4  [balanc, wife, account, say, suspend]      192      138       42
#
#                               topics_threshold_>=0.5  \
# 0          [12, 24, 26, 31, 33, 42, 46, 66, 92, 100]
# 1  [22, 27, 42, 66, 81, 92, 99, 100, 101, 104, 11...
# 2            [8, 61, 66, 85, 99, 104, 136, 177, 192]
# 3  [3, 17, 18, 33, 42, 46, 86, 92, 100, 104, 147,...
# 4  [29, 31, 35, 42, 48, 61, 71, 73, 101, 110, 116...
#
#                              topics_threshold_>=0.75  \
# 0                                   [12, 31, 66, 92]
# 1               [27, 42, 66, 81, 100, 104, 148, 177]
# 2                         [8, 66, 99, 104, 136, 177]
# 3                     [3, 42, 46, 92, 100, 104, 177]
# 4  [35, 42, 48, 61, 71, 73, 101, 110, 138, 150, 1...
#
#                                    topic_1_key_words  \
# 0  [(activ, sim), (speak, agent), (sim, card), (c...
# 1  [(got, payment), (ts, get), (get, bill), (got,...
# 2  [(account, detail), (just, want), (phone, bill...
# 3  [(gb, freedom), (freedom, data), (cancel, serv...
# 4  [(mytab, balanc), (samsung, galaxi), (check, m...
#
#                                    topic_2_key_words  \
# 0  [(want, activ), (activ, sim), (tri, activ), (r...
# 1  [(pay, remain), (remain, balanc), (need, talk)...
# 2  [(gb, freedom), (freedom, data), (cancel, serv...
# 3  [(want, cancel), (cancel, plan), (need, cancel...
# 4  [(transcript, url), (url, https://freedomcusto...
#
#                                    topic_3_key_words
# 0  [(abl, pay), (possibl, sim), (sim, card), (car...
# 1  [(data, talk), (upgrad, phone), (just, receiv)...
# 2  [(activ, sim), (speak, agent), (sim, card), (c...
# 3  [(data, talk), (upgrad, phone), (just, receiv)...
# 4  [(pay, remain), (remain, balanc), (need, talk)...

# %%
df_topics2[df_topics2["topic_3"]==9]
# Out:
#                            conversation_id  message_id  \
# 22    0150b1e8-7800-47c9-934c-1f8dabbb1a01          11
# 27    01793a58-8e8b-4c25-af7d-cd486259eed2           8
# 59    036cd2b1-ee8f-411b-8025-7a55f09878f8          14
# 137   0d084769-c927-4fe1-b26c-cf0bd7e8e90a           1
# 219   12b62db5-ab6e-44e1-83f0-d5405365a4df           1
# 227                       1396070490425721          11
# 228                       1396070490425721          16
# 255                       1630882257015503           3
# 258                       1630882257015503          16
# 280                       1844269545616220           3
# 281                       1844269545616220           5
# 382   1e2a7ce2-d268-4825-879b-2f80e756f4d1           1
# 397   1fb0c301-9ca7-4d42-b280-aa400d41e6de           1
# 694                       3467351136698676          12
# 819                       3814075465356746           3
# 891                       3920233574697442           3
# 916                       3988408344614034          12
# 925   3c5f299e-28b0-4fcc-85bd-81bc09090c40           1
# 1005                      4100098910034213           1
# 1015  41026cbd-5167-4bc0-be4e-6414e4f61611           7
# 1088  4446f996-dc9b-4987-beeb-8647d08a5c1e           1
# 1120  48130c88-0060-47d0-9baa-90634caf76df           1
# 1149  4a00ef2d-2c42-4123-8abf-5f05f96b3ac2           4
# 1233  532c21d2-9443-487d-bc11-ea832a1da694           4
# 1266  53db01ec-5cdf-497c-9486-611722e0708d           1
# 1332  5a7043f6-7272-4eda-8e65-eef5ea39d8fc           4
# 1368  5e3622a9-bea9-4cdd-8e54-e04bbc8f29e6           1
# 1397  6022faa6-d2f6-4207-8ff8-c6659ff77822           6
# 1461  66459401-9389-48ac-bb36-ed2a67a5d274          13
# 1510  6a43dfe6-1c0c-4d11-9906-6944ce44184e           3
# ...                                    ...         ...
# 1654  7753ae50-f750-4a1d-9ca1-34397d259098           1
# 1701  7d0e2ec6-83fe-486a-9fee-e67438e5d15b           3
# 1738  810fc912-da22-4f41-b9b7-0af3786869d3           3
# 1742  81e819dd-b80b-4a36-853b-a492d3d83e2b          11
# 1812  8a88936c-1637-439e-80b7-aa8fd379fc3b           1
# 1911  95681366-fd6e-4ff9-8bbd-648b90af641d          11
# 1918  9618291b-5b8b-4771-92ae-13462526e45c           1
# 1984  9d46ea73-8d23-4fcb-a668-f09f49d308de           2
# 2029  a0d67af3-f0d2-47be-9ae1-6eb933c6826e           1
# 2077  a5a1cdb2-0847-4aab-873a-18ecc687157e          11
# 2112  a9a231b6-84b5-4a18-8c13-c2c4c6d870f1          12
# 2147  acc9091c-c993-4c88-946c-e6c21f7f185c           1
# 2168  af4ce65b-b090-4463-9789-62805c7269f4           1
# 2190  b0d9f5dd-c84e-49b8-8886-cc60742950cb           4
# 2215  b553e941-ce10-49f0-b024-14f8f50770c9           1
# 2217  b553e941-ce10-49f0-b024-14f8f50770c9          11
# 2268  ba4bc3ba-5a53-4c30-92bd-c14a2336dfb0           1
# 2285  bbcd4505-e6e9-4f1a-a0e8-25efa63de7ce           5
# 2310  c0423b5a-21ea-4f86-8025-f8e1266c4160           1
# 2445  cf234b65-8502-4e05-96a7-e3ad2c5a38c3           1
# 2453  d0eb886f-72d3-479c-b7c6-c3909dc2c5b9          12
# 2503  d76cab8b-4c50-4160-a7b0-647963815b8f           1
# 2644  ed2f138e-6e52-4dff-8f52-0d2d155aeb37           8
# 2661  ee743ae8-f7ac-4d1f-b8b1-ed56172dfb63           1
# 2673  efac2d30-70eb-4391-9e0f-c7f8d6b3690e           2
# 2713  f59ed023-9de3-4836-9295-6a059b3030c2           1
# 2751  f7761d8c-3ac6-44fb-bf9f-2bf204b8c2fc           1
# 2806  fe4dff11-773a-4480-ac5b-4542d5e489e9           9
# 2809  fe8a47dd-d103-44a9-9d3f-d88400aa31d8           1
# 2822  ff9ac61f-8f98-4516-9342-7aa1177514d9          24
#
#                                                 MESSAGE  sentence_id  \
# 22                                   15 gb freedom data            2
# 27                          i want to cancel my payment            0
# 59                                   15 gb freedom data            2
# 137       i want a new phone but your site is acting up            0
# 219    freedom mobile iam having trouble for over on...            0
# 227                                  15 gb freedom data            2
# 228         i am with freedom mobile for over 10 years             5
# 255                   i want to cancel my home internet            0
# 258                                    i want to cancel            4
# 280                         i need to update my address            2
# 281                         i need to update my address            4
# 382                                      be/eiuskbm1rkm            1
# 397          i want to update the address on my account            0
# 694                   but there is no change in freedom            2
# 819   if i knew freedom was such a disgsuting compan...            4
# 891    i want to get a new line with you and have it...            0
# 916                           i want it though freedom             5
# 925                            i want to cancel my plan            0
# 1005       and with freedom mobile with the same years             2
# 1015                                 15 gb freedom data            7
# 1088  i want to download my last bill i cant because...            0
# 1120                 i need to cancel my cell insurance            0
# 1149  do i need to cancel with my current provider f...            3
# 1233                            i want to cancel it now            1
# 1266           i want to cancel two lines on my account            1
# 1332                        i want to update my address            0
# 1368                                    freedom mobile             0
# 1397                            freedom mobile costumer            1
# 1461                                 15 gb freedom data            5
# 1510                               i want cancel servic            0
# ...                                                 ...          ...
# 1654   i need to cancel one of my phone plans with f...            1
# 1701                        i need to update my address            0
# 1738                i need to update my current address            0
# 1742                                 15 gb freedom data            2
# 1812         a freedom 30 plan and a freedom 1 gb plan             2
# 1911                                 15 gb freedom data            2
# 1918                 i need to update my spping address            1
# 1984   why freedom mobile keep charging me wle i 'm ...            2
# 2029                  i want to cancel my home internet            0
# 2077                                 15 gb freedom data            2
# 2112                                 15 gb freedom data            2
# 2147   i want to cancel a phone number under my account            0
# 2168             i need to cancel my home internet plan            1
# 2190                        i want to cancel my service            0
# 2215   i want to update my mailing address in my fre...            1
# 2217   i want to update my mailing address in my fre...            4
# 2268  i need to cancel our home internet effective t...            0
# 2285                                     freedom mobile            8
# 2310  i need to cancel my subscription of freedom mo...            0
# 2445             i want to cancel my line with you guys            1
# 2453                                 15 gb freedom data            2
# 2503                        i need to cancel my account            1
# 2644                           i want to cancel my plan            2
# 2661                        i want to cancel my service            0
# 2673                           can't log into myfreedom            0
# 2713        i want to cancel my phone protection plan 9            0
# 2751            i want to cancel the plan for ts number            0
# 2806                                      want new plan            1
# 2809            i need to cancel my mother's phone plan            1
# 2822                                 15 gb freedom data            5
#
#                                   session_id  word_count  \
# 22    0150b1e8-7800-47c9-934c-1f8dabbb1a01_2           4
# 27    01793a58-8e8b-4c25-af7d-cd486259eed2_0           6
# 59    036cd2b1-ee8f-411b-8025-7a55f09878f8_2           4
# 137   0d084769-c927-4fe1-b26c-cf0bd7e8e90a_0          11
# 219   12b62db5-ab6e-44e1-83f0-d5405365a4df_0          61
# 227                       1396070490425721_2           4
# 228                       1396070490425721_5          11
# 255                       1630882257015503_0           7
# 258                       1630882257015503_4           4
# 280                       1844269545616220_2           6
# 281                       1844269545616220_4           6
# 382   1e2a7ce2-d268-4825-879b-2f80e756f4d1_1           2
# 397   1fb0c301-9ca7-4d42-b280-aa400d41e6de_0          10
# 694                       3467351136698676_2           7
# 819                       3814075465356746_4          21
# 891                       3920233574697442_0          29
# 916                       3988408344614034_5           6
# 925   3c5f299e-28b0-4fcc-85bd-81bc09090c40_0           7
# 1005                      4100098910034213_2          10
# 1015  41026cbd-5167-4bc0-be4e-6414e4f61611_7           4
# 1088  4446f996-dc9b-4987-beeb-8647d08a5c1e_0          16
# 1120  48130c88-0060-47d0-9baa-90634caf76df_0           7
# 1149  4a00ef2d-2c42-4123-8abf-5f05f96b3ac2_3          10
# 1233  532c21d2-9443-487d-bc11-ea832a1da694_1           6
# 1266  53db01ec-5cdf-497c-9486-611722e0708d_1          10
# 1332  5a7043f6-7272-4eda-8e65-eef5ea39d8fc_0           6
# 1368  5e3622a9-bea9-4cdd-8e54-e04bbc8f29e6_0           4
# 1397  6022faa6-d2f6-4207-8ff8-c6659ff77822_1           3
# 1461  66459401-9389-48ac-bb36-ed2a67a5d274_5           4
# 1510  6a43dfe6-1c0c-4d11-9906-6944ce44184e_0           4
# ...                                      ...         ...
# 1654  7753ae50-f750-4a1d-9ca1-34397d259098_1          12
# 1701  7d0e2ec6-83fe-486a-9fee-e67438e5d15b_0           6
# 1738  810fc912-da22-4f41-b9b7-0af3786869d3_0           7
# 1742  81e819dd-b80b-4a36-853b-a492d3d83e2b_2           4
# 1812  8a88936c-1637-439e-80b7-aa8fd379fc3b_2          12
# 1911  95681366-fd6e-4ff9-8bbd-648b90af641d_2           4
# 1918  9618291b-5b8b-4771-92ae-13462526e45c_1           9
# 1984  9d46ea73-8d23-4fcb-a668-f09f49d308de_2          16
# 2029  a0d67af3-f0d2-47be-9ae1-6eb933c6826e_0           7
# 2077  a5a1cdb2-0847-4aab-873a-18ecc687157e_2           4
# 2112  a9a231b6-84b5-4a18-8c13-c2c4c6d870f1_2           4
# 2147  acc9091c-c993-4c88-946c-e6c21f7f185c_0          11
# 2168  af4ce65b-b090-4463-9789-62805c7269f4_1           9
# 2190  b0d9f5dd-c84e-49b8-8886-cc60742950cb_0           6
# 2215  b553e941-ce10-49f0-b024-14f8f50770c9_1          13
# 2217  b553e941-ce10-49f0-b024-14f8f50770c9_4          13
# 2268  ba4bc3ba-5a53-4c30-92bd-c14a2336dfb0_0          20
# 2285  bbcd4505-e6e9-4f1a-a0e8-25efa63de7ce_8           3
# 2310  c0423b5a-21ea-4f86-8025-f8e1266c4160_0           9
# 2445  cf234b65-8502-4e05-96a7-e3ad2c5a38c3_1          10
# 2453  d0eb886f-72d3-479c-b7c6-c3909dc2c5b9_2           4
# 2503  d76cab8b-4c50-4160-a7b0-647963815b8f_1           7
# 2644  ed2f138e-6e52-4dff-8f52-0d2d155aeb37_2           6
# 2661  ee743ae8-f7ac-4d1f-b8b1-ed56172dfb63_0           6
# 2673  efac2d30-70eb-4391-9e0f-c7f8d6b3690e_0           4
# 2713  f59ed023-9de3-4836-9295-6a059b3030c2_0           9
# 2751  f7761d8c-3ac6-44fb-bf9f-2bf204b8c2fc_0          10
# 2806  fe4dff11-773a-4480-ac5b-4542d5e489e9_1           3
# 2809  fe8a47dd-d103-44a9-9d3f-d88400aa31d8_1           9
# 2822  ff9ac61f-8f98-4516-9342-7aa1177514d9_5           4
#
#                                          processed_text  topic_1  topic_2  \
# 22                                  [gb, freedom, data]      177      104
# 27                              [want, cancel, payment]        3      142
# 59                                  [gb, freedom, data]      177      104
# 137                       [want, new, phone, site, act]       14       15
# 219   [freedom, mobil, iam, have, troubl, year, get,...       73      177
# 227                                 [gb, freedom, data]      177      104
# 228                              [freedom, mobil, year]       73      177
# 255                      [want, cancel, home, internet]        3      142
# 258                                      [want, cancel]        3      142
# 280                              [need, updat, address]       18      175
# 281                              [need, updat, address]       18      175
# 382                                      [eiuskbm, rkm]       81      142
# 397                     [want, updat, address, account]       18      104
# 694                                    [chang, freedom]       13       18
# 819   [knew, freedom, disgsut, compani, deal, chosen...       66       13
# 891   [want, new, line, activ, esim, phone, line, us...       14       15
# 916                                     [want, freedom]       13      142
# 925                                [want, cancel, plan]        3      142
# 1005                             [freedom, mobil, year]       73      177
# 1015                                [gb, freedom, data]      177      104
# 1088      [want, download, bill, account, unabl, login]      142      138
# 1120                        [need, cancel, cell, insur]        3      142
# 1149                    [need, cancel, current, provid]        3      142
# 1233                                     [want, cancel]        3      142
# 1266                      [want, cancel, line, account]        3      142
# 1332                             [want, updat, address]       18      104
# 1368                                   [freedom, mobil]       73      177
# 1397                           [freedom, mobil, costum]       73      177
# 1461                                [gb, freedom, data]      177      104
# 1510                             [want, cancel, servic]        3      142
# ...                                                 ...      ...      ...
# 1654               [need, cancel, phone, plan, freedom]        3      142
# 1701                             [need, updat, address]       18      175
# 1738                    [need, updat, current, address]       18      175
# 1742                                [gb, freedom, data]      177      104
# 1812                 [freedom, plan, freedom, gb, plan]       13       18
# 1911                                [gb, freedom, data]      177      104
# 1918                     [need, updat, spping, address]       18      175
# 1984    [freedom, mobil, charg, wle, use, card, anymor]       73      177
# 2029                     [want, cancel, home, internet]        3      142
# 2077                                [gb, freedom, data]      177      104
# 2112                                [gb, freedom, data]      177      104
# 2147             [want, cancel, phone, number, account]        3      142
# 2168               [need, cancel, home, internet, plan]        3      142
# 2190                             [want, cancel, servic]        3      142
# 2215     [want, updat, mail, address, freedom, account]       18      104
# 2217     [want, updat, mail, address, freedom, account]       18      104
# 2268  [need, cancel, home, internet, effect, today, ...        3      142
# 2285                                   [freedom, mobil]       73      177
# 2310          [need, cancel, subscript, freedom, mobil]        3      142
# 2445                          [want, cancel, line, guy]        3      142
# 2453                                [gb, freedom, data]      177      104
# 2503                            [need, cancel, account]        3      142
# 2644                               [want, cancel, plan]        3      142
# 2661                             [want, cancel, servic]        3      142
# 2673                                   [log, myfreedom]      142       42
# 2713               [want, cancel, phone, protect, plan]        3      142
# 2751                   [want, cancel, plan, ts, number]        3      142
# 2806                                  [want, new, plan]       14       15
# 2809                [need, cancel, mother, phone, plan]        3      142
# 2822                                [gb, freedom, data]      177      104
#
#       topic_3                             topics_threshold_>=0.5  \
# 22          9  [9, 10, 13, 15, 18, 21, 27, 28, 33, 37, 46, 92...
# 27          9                           [3, 9, 24, 42, 142, 150]
# 59          9  [9, 10, 13, 15, 18, 21, 27, 28, 33, 37, 46, 92...
# 137         9     [9, 14, 15, 24, 28, 31, 42, 71, 126, 142, 144]
# 219         9        [9, 13, 24, 72, 73, 81, 105, 128, 142, 177]
# 227         9  [9, 10, 13, 15, 18, 21, 27, 28, 33, 37, 46, 92...
# 228         9        [9, 13, 24, 72, 73, 81, 105, 128, 142, 177]
# 255         9                           [3, 9, 24, 42, 142, 150]
# 258         9                           [3, 9, 24, 42, 142, 150]
# 280         9  [9, 18, 28, 31, 33, 65, 71, 73, 75, 81, 100, 1...
# 281         9  [9, 18, 28, 31, 33, 65, 71, 73, 75, 81, 100, 1...
# 382         9  [9, 15, 18, 21, 24, 66, 73, 77, 81, 104, 105, ...
# 397         9  [9, 18, 31, 71, 73, 75, 81, 99, 104, 115, 142,...
# 694         9  [6, 9, 13, 15, 18, 28, 42, 66, 72, 92, 95, 136...
# 819         9  [9, 13, 14, 18, 24, 42, 66, 73, 81, 95, 104, 1...
# 891         9     [9, 14, 15, 24, 28, 31, 42, 71, 126, 142, 144]
# 916         9  [9, 10, 13, 15, 18, 24, 28, 42, 66, 104, 141, ...
# 925         9                           [3, 9, 24, 42, 142, 150]
# 1005        9        [9, 13, 24, 72, 73, 81, 105, 128, 142, 177]
# 1015        9  [9, 10, 13, 15, 18, 21, 27, 28, 33, 37, 46, 92...
# 1088        9  [9, 15, 22, 27, 42, 50, 71, 81, 104, 111, 115,...
# 1120        9                               [3, 9, 18, 142, 150]
# 1149        9                               [3, 9, 18, 142, 150]
# 1233        9                           [3, 9, 24, 42, 142, 150]
# 1266        9                           [3, 9, 24, 42, 142, 150]
# 1332        9  [9, 18, 31, 71, 73, 75, 81, 99, 104, 115, 142,...
# 1368        9        [9, 13, 24, 72, 73, 81, 105, 128, 142, 177]
# 1397        9        [9, 13, 24, 72, 73, 81, 105, 128, 142, 177]
# 1461        9  [9, 10, 13, 15, 18, 21, 27, 28, 33, 37, 46, 92...
# 1510        9                           [3, 9, 24, 42, 142, 150]
# ...       ...                                                ...
# 1654        9                               [3, 9, 18, 142, 150]
# 1701        9  [9, 18, 28, 31, 33, 65, 71, 73, 75, 81, 100, 1...
# 1738        9  [9, 18, 28, 31, 33, 65, 71, 73, 75, 81, 100, 1...
# 1742        9  [9, 10, 13, 15, 18, 21, 27, 28, 33, 37, 46, 92...
# 1812        9  [9, 10, 13, 18, 28, 30, 33, 66, 95, 141, 142, ...
# 1911        9  [9, 10, 13, 15, 18, 21, 27, 28, 33, 37, 46, 92...
# 1918        9  [9, 18, 28, 31, 33, 65, 71, 73, 75, 81, 100, 1...
# 1984        9        [9, 13, 24, 72, 73, 81, 105, 128, 142, 177]
# 2029        9                           [3, 9, 24, 42, 142, 150]
# 2077        9  [9, 10, 13, 15, 18, 21, 27, 28, 33, 37, 46, 92...
# 2112        9  [9, 10, 13, 15, 18, 21, 27, 28, 33, 37, 46, 92...
# 2147        9                           [3, 9, 24, 42, 142, 150]
# 2168        9                               [3, 9, 18, 142, 150]
# 2190        9                           [3, 9, 24, 42, 142, 150]
# 2215        9  [9, 18, 31, 71, 73, 75, 81, 99, 104, 115, 142,...
# 2217        9  [9, 18, 31, 71, 73, 75, 81, 99, 104, 115, 142,...
# 2268        9                               [3, 9, 18, 142, 150]
# 2285        9        [9, 13, 24, 72, 73, 81, 105, 128, 142, 177]
# 2310        9                               [3, 9, 18, 142, 150]
# 2445        9                           [3, 9, 24, 42, 142, 150]
# 2453        9  [9, 10, 13, 15, 18, 21, 27, 28, 33, 37, 46, 92...
# 2503        9                               [3, 9, 18, 142, 150]
# 2644        9                           [3, 9, 24, 42, 142, 150]
# 2661        9                           [3, 9, 24, 42, 142, 150]
# 2673        9  [8, 9, 13, 22, 31, 37, 42, 46, 99, 100, 104, 1...
# 2713        9                           [3, 9, 24, 42, 142, 150]
# 2751        9                           [3, 9, 24, 42, 142, 150]
# 2806        9     [9, 14, 15, 24, 28, 31, 42, 71, 126, 142, 144]
# 2809        9                               [3, 9, 18, 142, 150]
# 2822        9  [9, 10, 13, 15, 18, 21, 27, 28, 33, 37, 46, 92...
#
#                                 topics_threshold_>=0.75  \
# 22                   [9, 13, 21, 27, 92, 104, 138, 177]
# 27                                          [3, 9, 142]
# 59                   [9, 13, 21, 27, 92, 104, 138, 177]
# 137                                 [9, 14, 15, 24, 42]
# 219                               [9, 13, 73, 142, 177]
# 227                  [9, 13, 21, 27, 92, 104, 138, 177]
# 228                               [9, 13, 73, 142, 177]
# 255                                         [3, 9, 142]
# 258                                         [3, 9, 142]
# 280                            [9, 18, 28, 31, 71, 175]
# 281                            [9, 18, 28, 31, 71, 175]
# 382   [9, 18, 21, 24, 66, 73, 81, 104, 133, 136, 142...
# 397                       [9, 18, 71, 75, 81, 104, 175]
# 694                         [6, 9, 13, 18, 66, 92, 177]
# 819              [9, 13, 14, 18, 66, 81, 142, 161, 192]
# 891                                 [9, 14, 15, 24, 42]
# 916                           [9, 13, 18, 66, 104, 142]
# 925                                         [3, 9, 142]
# 1005                              [9, 13, 73, 142, 177]
# 1015                 [9, 13, 21, 27, 92, 104, 138, 177]
# 1088  [9, 22, 42, 81, 104, 121, 138, 142, 148, 161, ...
# 1120                                        [3, 9, 142]
# 1149                                        [3, 9, 142]
# 1233                                        [3, 9, 142]
# 1266                                        [3, 9, 142]
# 1332                      [9, 18, 71, 75, 81, 104, 175]
# 1368                              [9, 13, 73, 142, 177]
# 1397                              [9, 13, 73, 142, 177]
# 1461                 [9, 13, 21, 27, 92, 104, 138, 177]
# 1510                                        [3, 9, 142]
# ...                                                 ...
# 1654                                        [3, 9, 142]
# 1701                           [9, 18, 28, 31, 71, 175]
# 1738                           [9, 18, 28, 31, 71, 175]
# 1742                 [9, 13, 21, 27, 92, 104, 138, 177]
# 1812                            [9, 13, 18, 28, 66, 95]
# 1911                 [9, 13, 21, 27, 92, 104, 138, 177]
# 1918                           [9, 18, 28, 31, 71, 175]
# 1984                              [9, 13, 73, 142, 177]
# 2029                                        [3, 9, 142]
# 2077                 [9, 13, 21, 27, 92, 104, 138, 177]
# 2112                 [9, 13, 21, 27, 92, 104, 138, 177]
# 2147                                        [3, 9, 142]
# 2168                                        [3, 9, 142]
# 2190                                        [3, 9, 142]
# 2215                      [9, 18, 71, 75, 81, 104, 175]
# 2217                      [9, 18, 71, 75, 81, 104, 175]
# 2268                                        [3, 9, 142]
# 2285                              [9, 13, 73, 142, 177]
# 2310                                        [3, 9, 142]
# 2445                                        [3, 9, 142]
# 2453                 [9, 13, 21, 27, 92, 104, 138, 177]
# 2503                                        [3, 9, 142]
# 2644                                        [3, 9, 142]
# 2661                                        [3, 9, 142]
# 2673  [9, 13, 22, 31, 37, 42, 46, 100, 104, 138, 142...
# 2713                                        [3, 9, 142]
# 2751                                        [3, 9, 142]
# 2806                                [9, 14, 15, 24, 42]
# 2809                                        [3, 9, 142]
# 2822                 [9, 13, 21, 27, 92, 104, 138, 177]
#
#                                       topic_1_key_words  \
# 22    [(gb, freedom), (freedom, data), (cancel, serv...
# 27    [(want, cancel), (cancel, plan), (need, cancel...
# 59    [(gb, freedom), (freedom, data), (cancel, serv...
# 137   [(new, phone), (new, sim), (activ, new), (sim,...
# 219   [(freedom, mobil), (wind, mobil), (mobil, year...
# 227   [(gb, freedom), (freedom, data), (cancel, serv...
# 228   [(freedom, mobil), (wind, mobil), (mobil, year...
# 255   [(want, cancel), (cancel, plan), (need, cancel...
# 258   [(want, cancel), (cancel, plan), (need, cancel...
# 280   [(need, chang), (chang, address), (updat, addr...
# 281   [(need, chang), (chang, address), (updat, addr...
# 382   [(pay, bill), (hey, want), (phone, card), (guy...
# 397   [(need, chang), (chang, address), (updat, addr...
# 694   [(freedom, receiv), (receiv, account), (accoun...
# 819   [(activ, sim), (speak, agent), (sim, card), (c...
# 891   [(new, phone), (new, sim), (activ, new), (sim,...
# 916   [(freedom, receiv), (receiv, account), (accoun...
# 925   [(want, cancel), (cancel, plan), (need, cancel...
# 1005  [(freedom, mobil), (wind, mobil), (mobil, year...
# 1015  [(gb, freedom), (freedom, data), (cancel, serv...
# 1088  [(pay, bill), (want, pay), (add, line), (make,...
# 1120  [(want, cancel), (cancel, plan), (need, cancel...
# 1149  [(want, cancel), (cancel, plan), (need, cancel...
# 1233  [(want, cancel), (cancel, plan), (need, cancel...
# 1266  [(want, cancel), (cancel, plan), (need, cancel...
# 1332  [(need, chang), (chang, address), (updat, addr...
# 1368  [(freedom, mobil), (wind, mobil), (mobil, year...
# 1397  [(freedom, mobil), (wind, mobil), (mobil, year...
# 1461  [(gb, freedom), (freedom, data), (cancel, serv...
# 1510  [(want, cancel), (cancel, plan), (need, cancel...
# ...                                                 ...
# 1654  [(want, cancel), (cancel, plan), (need, cancel...
# 1701  [(need, chang), (chang, address), (updat, addr...
# 1738  [(need, chang), (chang, address), (updat, addr...
# 1742  [(gb, freedom), (freedom, data), (cancel, serv...
# 1812  [(freedom, receiv), (receiv, account), (accoun...
# 1911  [(gb, freedom), (freedom, data), (cancel, serv...
# 1918  [(need, chang), (chang, address), (updat, addr...
# 1984  [(freedom, mobil), (wind, mobil), (mobil, year...
# 2029  [(want, cancel), (cancel, plan), (need, cancel...
# 2077  [(gb, freedom), (freedom, data), (cancel, serv...
# 2112  [(gb, freedom), (freedom, data), (cancel, serv...
# 2147  [(want, cancel), (cancel, plan), (need, cancel...
# 2168  [(want, cancel), (cancel, plan), (need, cancel...
# 2190  [(want, cancel), (cancel, plan), (need, cancel...
# 2215  [(need, chang), (chang, address), (updat, addr...
# 2217  [(need, chang), (chang, address), (updat, addr...
# 2268  [(want, cancel), (cancel, plan), (need, cancel...
# 2285  [(freedom, mobil), (wind, mobil), (mobil, year...
# 2310  [(want, cancel), (cancel, plan), (need, cancel...
# 2445  [(want, cancel), (cancel, plan), (need, cancel...
# 2453  [(gb, freedom), (freedom, data), (cancel, serv...
# 2503  [(want, cancel), (cancel, plan), (need, cancel...
# 2644  [(want, cancel), (cancel, plan), (need, cancel...
# 2661  [(want, cancel), (cancel, plan), (need, cancel...
# 2673  [(pay, bill), (want, pay), (add, line), (make,...
# 2713  [(want, cancel), (cancel, plan), (need, cancel...
# 2751  [(want, cancel), (cancel, plan), (need, cancel...
# 2806  [(new, phone), (new, sim), (activ, new), (sim,...
# 2809  [(want, cancel), (cancel, plan), (need, cancel...
# 2822  [(gb, freedom), (freedom, data), (cancel, serv...
#
#                                       topic_2_key_words topic_3_key_words
# 22    [(account, detail), (just, want), (phone, bill...               NaN
# 27    [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 59    [(account, detail), (just, want), (phone, bill...               NaN
# 137   [(sim, card), (phone, number), (account, numbe...               NaN
# 219   [(gb, freedom), (freedom, data), (cancel, serv...               NaN
# 227   [(account, detail), (just, want), (phone, bill...               NaN
# 228   [(gb, freedom), (freedom, data), (cancel, serv...               NaN
# 255   [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 258   [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 280   [(reset, pin), (need, reset), (reset, voicemai...               NaN
# 281   [(reset, pin), (need, reset), (reset, voicemai...               NaN
# 382   [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 397   [(account, detail), (just, want), (phone, bill...               NaN
# 694   [(need, chang), (chang, address), (updat, addr...               NaN
# 819   [(freedom, receiv), (receiv, account), (accoun...               NaN
# 891   [(sim, card), (phone, number), (account, numbe...               NaN
# 916   [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 925   [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 1005  [(gb, freedom), (freedom, data), (cancel, serv...               NaN
# 1015  [(account, detail), (just, want), (phone, bill...               NaN
# 1088  [(transcript, url), (url, https://freedomcusto...               NaN
# 1120  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 1149  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 1233  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 1266  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 1332  [(account, detail), (just, want), (phone, bill...               NaN
# 1368  [(gb, freedom), (freedom, data), (cancel, serv...               NaN
# 1397  [(gb, freedom), (freedom, data), (cancel, serv...               NaN
# 1461  [(account, detail), (just, want), (phone, bill...               NaN
# 1510  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# ...                                                 ...               ...
# 1654  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 1701  [(reset, pin), (need, reset), (reset, voicemai...               NaN
# 1738  [(reset, pin), (need, reset), (reset, voicemai...               NaN
# 1742  [(account, detail), (just, want), (phone, bill...               NaN
# 1812  [(need, chang), (chang, address), (updat, addr...               NaN
# 1911  [(account, detail), (just, want), (phone, bill...               NaN
# 1918  [(reset, pin), (need, reset), (reset, voicemai...               NaN
# 1984  [(gb, freedom), (freedom, data), (cancel, serv...               NaN
# 2029  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2077  [(account, detail), (just, want), (phone, bill...               NaN
# 2112  [(account, detail), (just, want), (phone, bill...               NaN
# 2147  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2168  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2190  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2215  [(account, detail), (just, want), (phone, bill...               NaN
# 2217  [(account, detail), (just, want), (phone, bill...               NaN
# 2268  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2285  [(gb, freedom), (freedom, data), (cancel, serv...               NaN
# 2310  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2445  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2453  [(account, detail), (just, want), (phone, bill...               NaN
# 2503  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2644  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2661  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2673  [(pay, remain), (remain, balanc), (need, talk)...               NaN
# 2713  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2751  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2806  [(sim, card), (phone, number), (account, numbe...               NaN
# 2809  [(pay, bill), (want, pay), (add, line), (make,...               NaN
# 2822  [(account, detail), (just, want), (phone, bill...               NaN
#
# [67 rows x 15 columns]

# %% [markdown]
# # NMF on single-word sentences
#
# Currently not doing

# %% [markdown]
# # Aggregate at conversation level text

# %%
# TODO: Combine df_topics_1 and df_topics_2

# df_topics_final

# %%
# sort by conversation and sentence id to ensure order
df_conv_topics = df_topic_final.sort_values(by=["conversation_id", "sentence_id"])

# %%
# check 
# df_conv_topics[df_conv_topics["conversation_id"]=="1895298307224761"]

# %%
df_conv_topics["concat_text"] = df_conv_topics.groupby(["conversation_id"])["MESSAGE"].transform(
                lambda x: " ".join(x)
            )

# generate new dfs
df_conv_concat_text = df_conv_topics.groupby(["conversation_id"])["processed_text"].agg(sum).reset_index(name="preprocessed_concat_text")
df_combined_topics = df_conv_topics.groupby(["conversation_id"])["topic"].apply(list).reset_index(name="combined_topics")
df_combined_key_words = df_conv_topics.groupby(["conversation_id"])["topic_key_words"].apply(list).reset_index(name="combined_topic_key_words")

# %%
# join dfs
df_conv_topics = df_conv_topics.merge(df_conv_concat_text, on="conversation_id")\
                    .merge(df_combined_topics, on="conversation_id")\
                    .merge(df_combined_key_words, on="conversation_id")\
                    .drop_duplicates(subset=["conversation_id"])\
                    .reset_index()\
                    [["conversation_id", "concat_text", "preprocessed_concat_text", "combined_topics", "combined_topic_key_words"]]

# %%
df_conv_topics.tail(5)

# %%
# check 
# df_conv_topics[df_conv_topics["conversation_id"]=="1895298307224761"]

# %% [markdown]
# # Saving

# %%
# save results, vectorizer, and nmf model
df_topic_final.to_csv(f"nmf_topics/{save_folder}/freedom_msg_level_nmf_clusters.csv", index=False)
df_conv_topics.to_csv(f"nmf_topics/{save_folder}/freedom_conv_level_nmf_clusters.csv", index=False)
dump(tfidf_vectorizer, f"nmf_models/{save_folder}/msg_level_vectorizer.joblib")
dump(nmf, f"nmf_models/{save_folder}/msg_level_nmf.joblib")
